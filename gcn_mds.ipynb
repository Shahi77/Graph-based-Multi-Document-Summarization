# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahi77/Graph-based-Multi-Document-Summarization/blob/main/gcn_mds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Check if the files exist
print(os.listdir('/content/drive/My Drive/Colab Notebooks/datasets/final/'))
# Out:
# ['train_final_Vishwas.csv', 'SGM3.ipynb', 'test_final_Vishwas_corrected.json', 'train_final_Vishwas_corrected.json', 'bekaar.ipynb', 'test_final_Vishwas.csv', 'Summaries.zip', 'T5.ipynb', 'minilm_bal_exsum.pth', 'T5_model.pth', 'bekaar_SGM.ipynb', 'SBERT_Model_Ready.pth', 'Summary_Data_new', 'Whole_text_data', 'Summaries']

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# MDS On Whole_text_data

# %%
import os
import spacy
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load spaCy model for English
nlp = spacy.load('en_core_web_md')

# Path to the dataset
summaries_dir = '/content/drive/My Drive/Colab Notebooks/datasets/final/Whole_text_data'

# %%
# Function to read document clusters from the dataset directory
def read_document_cluster(summaries_dir):
    documents = []
    summaries_files = os.listdir(summaries_dir)

    for file_name in summaries_files:
        file_path = os.path.join(summaries_dir, file_name)
        try:
            with open(file_path, 'r') as file:
                documents.append(file.read())
        except Exception as e:
            print(f"Error reading {file_name}: {e}")
    return documents

# %%
import os
import spacy
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Define device for computation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Function to read document clusters from the dataset directory
def read_document_cluster(summaries_dir):
    documents = []
    summaries_files = os.listdir(summaries_dir)

    for file_name in summaries_files:
        file_path = os.path.join(summaries_dir, file_name)
        try:
            with open(file_path, 'r') as file:
                documents.append(file.read())
            print(f"Loaded {file_name}")
        except Exception as e:
            print(f"Error reading {file_name}: {e}")
    return documents

# Tokenization using spaCy
def tokenize_with_spacy(text, nlp):
    doc = nlp(text)
    return [token.text for token in doc]

# Get sentence embeddings using spaCy vectors
def get_embeddings_with_spacy(text, nlp):
    doc = nlp(text)
    return doc.vector  # Returns a 1D vector of the document

# Function to split document into sentences
def split_into_sentences(text):
    sentences = text.split('.')
    return [sentence.strip() for sentence in sentences if sentence]

# Custom function to calculate cosine similarity with a threshold
def cosine_similarity_threshold(embeddings, threshold=0.2):
    sim_matrix = cosine_similarity(embeddings)
    adj_matrix = (sim_matrix > threshold).astype(float)  # Apply threshold to create edges
    return adj_matrix

# Extract sentence features
def extract_sentence_features(sentences, nlp):
    features = []
    for i, sentence in enumerate(sentences):
        length = len(sentence.split())
        features.append({
            'position': i,
            'length': length,
            'proper_nouns': sum([1 for token in tokenize_with_spacy(sentence, nlp) if token.isupper()]),
            'is_first_three': 1 if i < 3 else 0
        })
    return features

# Calculate sentence personalization score
def calculate_personalization_scores(features):
    weights = {
        'position': 0.1,
        'length': 0.2,
        'proper_nouns': 0.4,
        'is_first_three': 0.3
    }
    personalization_scores = []
    for feature in features:
        score = sum([feature[key] * weights[key] for key in weights])
        personalization_scores.append(score)
    return personalization_scores

# Build the sentence relation graph using cosine similarity and personalization
def build_sentence_relation_graph(sentences, nlp, threshold=0.2):
    print(f"Building sentence relation graph for {len(sentences)} sentences.")
    sentence_embeddings = [get_embeddings_with_spacy(sentence, nlp) for sentence in sentences]
    sentence_embeddings = np.vstack(sentence_embeddings)
    print(f"Shape of sentence embeddings: {sentence_embeddings.shape}")

    adj_matrix = cosine_similarity_threshold(sentence_embeddings, threshold)
    print(f"Adjacency matrix shape: {adj_matrix.shape}")

    sentence_features = extract_sentence_features(sentences, nlp)
    personalization_scores = calculate_personalization_scores(sentence_features)
    print(f"Personalization scores: {personalization_scores}")

    for i in range(adj_matrix.shape[0]):
        for j in range(adj_matrix.shape[1]):
            if adj_matrix[i, j] > 0:
                adj_matrix[i, j] *= personalization_scores[i]

    adj_matrix = adj_matrix / adj_matrix.max()
    print("Adjacency matrix normalized.")
    return adj_matrix

# GRU-based Sentence Encoder
class GRUSentenceEncoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(GRUSentenceEncoder, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)

    def forward(self, x):
        _, h_n = self.gru(x)
        return h_n.squeeze(0)

# Processing document cluster through the GRU
def process_document_cluster_through_gru(documents, nlp, hidden_size=128):
    input_size = 300  # SpaCy vectors are 300-dimensional
    encoder = GRUSentenceEncoder(input_size, hidden_size).to(device)

    sentence_encodings = []
    for doc in documents:
        sentences = split_into_sentences(doc)
        print(f"Processing document with {len(sentences)} sentences.")
        sentence_embeddings = [torch.tensor(get_embeddings_with_spacy(sentence, nlp)).to(device) for sentence in sentences]
        embeddings_tensor = torch.stack(sentence_embeddings).unsqueeze(0).to(device)

        # Ensure that the input tensor shape is correct for GRU
        sentence_encoding = encoder(embeddings_tensor)
        sentence_encodings.append(sentence_encoding)

    return torch.stack(sentence_encodings)

# GCN Layer Definition
# class GCNLayer(nn.Module):
#     def __init__(self, in_channels, out_channels):
#         super(GCNLayer, self).__init__()
#         self.fc = nn.Linear(in_channels, out_channels)

#    def forward(self, x, adj):
#     # Normalize the adjacency matrix
#       adj = self.normalize_adj(adj)

#     # Check shapes before multiplication
#     `print(f"Shape of adj: {adj.shape}, Shape of x: {x.shape}")

#     # Ensure dimensions match
#     `if adj.shape[0] != x.shape[0]:
#         raise ValueError(f"Dimension mismatch: adj has {adj.shape[0]} nodes, but x has {x.shape[0]} features.")

#     # Perform the multiplication
#        x = torch.matmul(adj, x)
#        return F.relu(x)

#     def normalize_adj(self, adj):
#         num_nodes = adj.size(0)
#         I = torch.eye(num_nodes).to(device)
#         adj = adj + I
#         D = torch.sum(adj, dim=1)
#         D_inv_sqrt = torch.pow(D, -0.5)
#         D_inv_sqrt[torch.isinf(D_inv_sqrt)] = 0
#         D_inv_sqrt = torch.diag(D_inv_sqrt)
#         return torch.matmul(D_inv_sqrt, torch.matmul(adj, D_inv_sqrt))

class GCNLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCNLayer, self).__init__()
        self.fc = nn.Linear(in_channels, out_channels)

    def forward(self, x, adj):
        adj = self.normalize_adj(adj)
        assert adj.shape[0] == x.shape[0], "Dimension mismatch: adj and x must have the same number of nodes."

        x = torch.matmul(adj, x)
        return F.relu(x)

    def normalize_adj(self, adj):
        num_nodes = adj.size(0)
        I = torch.eye(num_nodes).to(device)
        adj = adj + I
        D = torch.sum(adj, dim=1)
        D_inv_sqrt = torch.pow(D, -0.5)
        D_inv_sqrt[torch.isinf(D_inv_sqrt)] = 0
        D_inv_sqrt = torch.diag(D_inv_sqrt)
        return torch.matmul(D_inv_sqrt, torch.matmul(adj, D_inv_sqrt))


# Read and process documents
summaries_dir = '/content/drive/My Drive/Colab Notebooks/datasets/final/Whole_text_data'  # Replace with actual path
documents = read_document_cluster(summaries_dir)
print(f"Loaded {len(documents)} documents.")

# Initialize spaCy
nlp = spacy.load('en_core_web_md')

# Split documents into sentences
sentences_per_document = [split_into_sentences(doc) for doc in documents]
print("Done splitting documents into sentences.")

# Build sentence relation graphs for each document
adj_matrices = [build_sentence_relation_graph(sentences, nlp) for sentences in sentences_per_document]
print("Done building adjacency matrices.")

# Process documents through GRU
sentence_encodings = process_document_cluster_through_gru(documents, nlp, hidden_size=128)
print(f"Processed document clusters through GRU. Shape: {sentence_encodings.shape}")

# Example usage of GCN layer
gcn = GCNLayer(128, 64).to(device)
# Convert adj_matrices to tensor and move to device
adj_tensor = torch.tensor(adj_matrices[0], dtype=torch.float32).to(device)

# Check the shape of the sentence encodings
print(f"Shape of sentence_encodings before: {sentence_encodings.shape}")

# Ensure the encodings have the correct dimensions [608, 128]
if len(sentence_encodings.shape) == 3 and sentence_encodings.shape[1] == 1:
    sentence_encodings = sentence_encodings.squeeze(1)  # Remove the second dimension

# Verify the final shape of sentence_encodings
print(f"Shape of sentence_encodings after: {sentence_encodings.shape}")

# Ensure adj_tensor has the right dimensions
print(f"Shape of adj_tensor: {adj_tensor.shape}")

# Apply the GCN layer to the sentence encodings and adjacency matrix
gcn_output = gcn(sentence_encodings, adj_tensor)

# Print the shape of the output
print("GCN output shape: ", gcn_output.shape)
# Out:
# Using device: cpu
# Loaded P02-1022.txt
# Loaded P02-1053.txt
# Loaded P95-1026.txt
# Loaded J90-1003.txt
# Loaded P06-1004.txt
# Loaded H05-1079.txt
# Loaded W04-3206.txt
# Loaded W03-0428.txt
# Loaded P93-1022.txt
# Loaded W06-2933.txt
# Loaded A94-1006.txt
# Loaded D08-1027.txt
# Loaded P05-1073.txt
# Loaded P04-1066.txt
# Loaded P04-1077.txt
# Loaded P95-1021.txt
# Loaded W02-0817.txt
# Loaded P03-1023.txt
# Loaded P02-1017.txt
# Loaded P08-1012.txt
# Loaded D09-1127.txt
# Loaded H05-1059.txt
# Loaded P06-2005.txt
# Loaded P06-2066.txt
# Loaded P07-1005.txt
# Loaded P01-1005.txt
# Loaded D11-1125.txt
# Loaded P97-1013.txt
# Loaded W06-0301.txt
# Loaded W07-2009.txt
# Loaded P11-1061.txt
# Loaded W97-0119.txt
# Loaded P02-1038.txt
# Loaded P98-2204.txt
# Loaded A00-1043.txt
# Loaded W02-0109.txt
# Loaded P03-1029.txt
# Loaded N06-1056.txt
# Loaded N03-1016.txt
# Loaded D09-1005.txt
# Loaded W03-0424.txt
# Loaded P06-1005.txt
# Loaded N06-1011.txt
# Loaded W06-1615.txt
# Loaded N04-1033.txt
# Loaded I05-2038.txt
# Loaded P04-3022.txt
# Loaded P99-1065.txt
# Loaded E03-1076.txt
# Loaded P93-1041.txt
# Loaded W97-0311.txt
# Loaded D07-1091.txt
# Loaded E03-1008.txt
# Loaded D07-1109.txt
# Loaded W03-0301.txt
# Loaded P98-2127.txt
# Loaded P96-1024.txt
# Loaded N01-1016.txt
# Loaded E89-1037.txt
# Loaded W00-0717.txt
# Loaded W04-3212.txt
# Loaded W02-2016.txt
# Loaded P01-1019.txt
# Loaded W97-0302.txt
# Loaded W06-1651.txt
# Loaded P89-1031.txt
# Loaded W00-1427.txt
# Loaded A92-1006.txt
# Loaded D07-1101.txt
# Loaded P05-1001.txt
# Loaded N10-1063.txt
# Loaded D09-1058.txt
# Loaded A00-2004.txt
# Loaded P07-1007.txt
# Loaded P03-1071.txt
# Loaded P04-1053.txt
# Loaded P07-1003.txt
# Loaded W07-0733.txt
# Loaded S12-1053.txt
# Loaded W01-1313.txt
# Loaded P90-1032.txt
# Loaded P88-1015.txt
# Loaded P91-1030.txt
# Loaded P11-2008.txt
# Loaded H05-1045.txt
# Loaded P06-1072.txt
# Loaded N01-1020.txt
# Loaded C02-1150.txt
# Loaded N09-1025.txt
# Loaded P04-1054.txt
# Loaded P08-1028.txt
# Loaded P98-1012.txt
# Loaded W07-2002.txt
# Loaded P06-2014.txt
# Loaded P02-1014.txt
# Loaded N07-1030.txt
# Loaded P07-1123.txt
# Loaded P06-1104.txt
# Loaded P07-1056.txt
# Loaded J88-2003.txt
# Loaded P98-1035.txt
# Loaded A00-1031.txt
# Loaded N04-1035.txt
# Loaded W06-1642.txt
# Loaded P04-1056.txt
# Loaded P99-1042.txt
# Loaded P05-1022.txt
# Loaded P11-1038.txt
# Loaded P93-1032.txt
# Loaded P03-1021.txt
# Loaded J86-3001.txt
# Loaded P10-1001.txt
# Loaded W09-0432.txt
# Loaded D08-1021.txt
# Loaded P06-1097.txt
# Loaded P03-1051.txt
# Loaded W04-3236.txt
# Loaded P04-1036.txt
# Loaded P09-1057.txt
# Loaded P10-1146.txt
# Loaded P00-1010.txt
# Loaded D08-1083.txt
# Loaded C08-1109.txt
# Loaded N04-1025.txt
# Loaded W08-0336.txt
# Loaded P07-1094.txt
# Loaded P09-1010.txt
# Loaded P96-1025.txt
# Loaded P08-1068.txt
# Loaded N09-1037.txt
# Loaded W06-1670.txt
# Loaded P02-1042.txt
# Loaded P01-1067.txt
# Loaded W01-0514.txt
# Loaded N07-1051.txt
# Loaded P07-1121.txt
# Loaded W11-0705.txt
# Loaded N09-1012.txt
# Loaded P97-1005.txt
# Loaded P10-1110.txt
# Loaded N04-1021.txt
# Loaded N03-1020.txt
# Loaded C04-1041.txt
# Loaded W09-1401.txt
# Loaded P09-1039.txt
# Loaded N01-1021.txt
# Loaded N10-1061.txt
# Loaded P99-1071.txt
# Loaded P05-1017.txt
# Loaded P08-1067.txt
# Loaded D09-1101.txt
# Loaded P98-1013.txt
# Loaded A00-2018.txt
# Loaded W02-1028.txt
# Loaded A00-2026.txt
# Loaded P06-1055.txt
# Loaded D08-1020.txt
# Loaded P99-1069.txt
# Loaded C10-1152.txt
# Loaded A92-1021.txt
# Loaded P06-1085.txt
# Loaded N07-1023.txt
# Loaded D07-1002.txt
# Loaded P01-1064.txt
# Loaded W03-1017.txt
# Loaded W98-1118.txt
# Loaded N06-1006.txt
# Loaded P07-1037.txt
# Loaded P02-1039.txt
# Loaded W95-0104.txt
# Loaded P02-1031.txt
# Loaded D09-1159.txt
# Loaded P09-1011.txt
# Loaded P08-1084.txt
# Loaded P00-1016.txt
# Loaded P03-1035.txt
# Loaded N07-1047.txt
# Loaded P06-1115.txt
# Loaded D07-1072.txt
# Loaded D12-1133.txt
# Loaded P93-1003.txt
# Loaded P08-1115.txt
# Loaded W04-1221.txt
# Loaded N10-1013.txt
# Loaded N04-1023.txt
# Loaded P06-1134.txt
# Loaded P93-1020.txt
# Loaded P08-1102.txt
# Loaded P02-1051.txt
# Loaded A97-1014.txt
# Loaded P03-1004.txt
# Loaded W04-2407.txt
# Loaded P05-1066.txt
# Loaded W00-0730.txt
# Loaded N10-1019.txt
# Loaded W07-1604.txt
# Loaded P03-1010.txt
# Loaded P11-1020.txt
# Loaded D10-1115.txt
# Loaded P08-1030.txt
# Loaded W03-1809.txt
# Loaded W99-0611.txt
# Loaded J88-1003.txt
# Loaded J87-1004.txt
# Loaded N06-1020.txt
# Loaded P02-1040.txt
# Loaded P95-1050.txt
# Loaded W98-0705.txt
# Loaded W96-0213.txt
# Loaded P04-1085.txt
# Loaded P04-1018.txt
# Loaded P07-1032.txt
# Loaded P07-1059.txt
# Loaded P07-1107.txt
# Loaded N04-4026.txt
# Loaded P07-1091.txt
# Loaded P09-1074.txt
# Loaded N10-1020.txt
# Loaded P09-1027.txt
# Loaded N04-1030.txt
# Loaded W06-3119.txt
# Loaded W11-1901.txt
# Loaded P08-1023.txt
# Loaded W02-0301.txt
# Loaded P08-1109.txt
# Loaded P06-1011.txt
# Loaded C10-2028.txt
# Loaded W02-1503.txt
# Loaded P13-1045.txt
# Loaded P99-1032.txt
# Loaded C04-1081.txt
# Loaded D08-1024.txt
# Loaded P09-1104.txt
# Loaded N04-1019.txt
# Loaded D08-1031.txt
# Loaded P98-1069.txt
# Loaded W03-0405.txt
# Loaded N03-1003.txt
# Loaded N12-1047.txt
# Loaded H05-1073.txt
# Loaded W96-0214.txt
# Loaded W97-0322.txt
# Loaded W04-3239.txt
# Loaded P08-1090.txt
# Loaded H05-1043.txt
# Loaded W04-3205.txt
# Loaded P03-1054.txt
# Loaded P07-1096.txt
# Loaded W04-0308.txt
# Loaded N03-1014.txt
# Loaded P10-1040.txt
# Loaded W02-0603.txt
# Loaded W04-3111.txt
# Loaded P02-1019.txt
# Loaded P07-1065.txt
# Loaded D08-1011.txt
# Loaded W07-0734.txt
# Loaded W06-2915.txt
# Loaded N01-1011.txt
# Loaded N06-1033.txt
# Loaded P06-1009.txt
# Loaded W99-0623.txt
# Loaded D07-1003.txt
# Loaded P02-1018.txt
# Loaded W97-0301.txt
# Loaded W99-0629.txt
# Loaded D11-1142.txt
# Loaded S10-1010.txt
# Loaded N06-1041.txt
# Loaded W02-0902.txt
# Loaded W06-1607.txt
# Loaded W02-1502.txt
# Loaded P05-3026.txt
# Loaded P03-1019.txt
# Loaded E06-1040.txt
# Loaded N04-1041.txt
# Loaded D09-1001.txt
# Loaded P07-1036.txt
# Loaded N06-1003.txt
# Loaded W04-3237.txt
# Loaded A00-2034.txt
# Loaded P03-1003.txt
# Loaded W11-2107.txt
# Loaded W09-1105.txt
# Loaded P09-1040.txt
# Loaded D07-1061.txt
# Loaded N01-1023.txt
# Loaded A97-1004.txt
# Loaded W08-0309.txt
# Loaded W97-0713.txt
# Loaded P97-1009.txt
# Loaded W05-1513.txt
# Loaded P98-1034.txt
# Loaded N06-1025.txt
# Loaded P94-1020.txt
# Loaded P03-1044.txt
# Loaded P05-1036.txt
# Loaded N06-1014.txt
# Loaded W04-0803.txt
# Loaded P91-1027.txt
# Loaded P12-1092.txt
# Loaded W93-0301.txt
# Loaded E06-1025.txt
# Loaded W01-0521.txt
# Loaded W00-0726.txt
# Loaded W08-2121.txt
# Loaded P04-1015.txt
# Loaded D08-1082.txt
# Loaded W00-0712.txt
# Loaded C04-1197.txt
# Loaded W99-0612.txt
# Loaded W02-1210.txt
# Loaded P05-1059.txt
# Loaded P06-2094.txt
# Loaded D07-1096.txt
# Loaded P07-1028.txt
# Loaded P01-1017.txt
# Loaded C08-1022.txt
# Loaded P05-1018.txt
# Loaded P00-1037.txt
# Loaded W07-0718.txt
# Loaded N03-1033.txt
# Loaded P04-1005.txt
# Loaded D09-1120.txt
# Loaded P97-1063.txt
# Loaded W06-3812.txt
# Loaded P87-1033.txt
# Loaded E03-1071.txt
# Loaded A97-1030.txt
# Loaded P96-1041.txt
# Loaded C08-1107.txt
# Loaded N01-1026.txt
# Loaded W04-3219.txt
# Loaded N04-1013.txt
# Loaded W07-2006.txt
# Loaded P99-1068.txt
# Loaded H05-1044.txt
# Loaded W06-3105.txt
# Loaded P04-1083.txt
# Loaded N06-1058.txt
# Loaded P06-1015.txt
# Loaded P06-1084.txt
# Loaded N04-1001.txt
# Loaded P98-1112.txt
# Loaded P03-1012.txt
# Loaded P06-2006.txt
# Loaded D08-1068.txt
# Loaded J88-2006.txt
# Loaded N06-1039.txt
# Loaded P04-1061.txt
# Loaded P05-1047.txt
# Loaded A00-2030.txt
# Loaded S10-1011.txt
# Loaded W03-1006.txt
# Loaded D08-1022.txt
# Loaded P07-1034.txt
# Loaded N03-1017.txt
# Loaded P07-1019.txt
# Loaded P93-1024.txt
# Loaded N09-1009.txt
# Loaded N09-1028.txt
# Loaded C02-1011.txt
# Loaded N09-1041.txt
# Loaded W07-0717.txt
# Loaded E03-1005.txt
# Loaded W04-1013.txt
# Loaded P91-1017.txt
# Loaded W99-0613.txt
# Loaded P03-1058.txt
# Loaded W03-1719.txt
# Loaded P09-1116.txt
# Loaded W98-1106.txt
# Loaded W00-1308.txt
# Loaded P03-2026.txt
# Loaded N01-1006.txt
# Loaded P06-1101.txt
# Loaded W06-1616.txt
# Loaded A00-2031.txt
# Loaded E06-1032.txt
# Loaded N10-1119.txt
# Loaded W95-0103.txt
# Loaded W09-1119.txt
# Loaded N01-1024.txt
# Loaded P99-1048.txt
# Loaded H05-1010.txt
# Loaded W06-2920.txt
# Loaded W97-0313.txt
# Loaded P00-1071.txt
# Loaded D09-1030.txt
# Loaded W01-0501.txt
# Loaded P03-1002.txt
# Loaded P96-1011.txt
# Loaded W08-0509.txt
# Loaded P08-2026.txt
# Loaded W02-2018.txt
# Loaded D07-1043.txt
# Loaded W95-0105.txt
# Loaded P09-1026.txt
# Loaded W10-0204.txt
# Loaded W10-2903.txt
# Loaded P98-2182.txt
# Loaded P05-1045.txt
# Loaded H05-1011.txt
# Loaded W05-1506.txt
# Loaded P07-1073.txt
# Loaded P05-1071.txt
# Loaded N09-1036.txt
# Loaded D11-1062.txt
# Loaded W03-0501.txt
# Loaded P06-1032.txt
# Loaded N07-1029.txt
# Loaded P04-1014.txt
# Loaded W02-2024.txt
# Loaded W07-2016.txt
# Loaded E99-1023.txt
# Loaded P10-1044.txt
# Loaded W04-2406.txt
# Loaded W04-0807.txt
# Loaded D07-1103.txt
# Loaded D09-1092.txt
# Loaded P09-1077.txt
# Loaded P06-1114.txt
# Loaded P06-1067.txt
# Loaded D10-1124.txt
# Loaded P08-1108.txt
# Loaded P08-1101.txt
# Loaded P06-1121.txt
# Loaded N01-1008.txt
# Loaded N12-1052.txt
# Loaded W02-1039.txt
# Loaded P07-1040.txt
# Loaded W04-3230.txt
# Loaded D11-1033.txt
# Loaded W06-3108.txt
# Loaded P94-1012.txt
# Loaded P05-1065.txt
# Loaded D08-1016.txt
# Loaded W07-1401.txt
# Loaded P09-1042.txt
# Loaded P96-1042.txt
# Loaded D07-1111.txt
# Loaded P99-1008.txt
# Loaded P93-1035.txt
# Loaded P08-1119.txt
# Loaded H05-1091.txt
# Loaded N03-1028.txt
# Loaded H05-1012.txt
# Loaded W11-1902.txt
# Loaded W07-2012.txt
# Loaded W03-1730.txt
# Loaded W03-0407.txt
# Loaded W05-0625.txt
# Loaded P99-1041.txt
# Loaded P05-1033.txt
# Loaded N07-1071.txt
# Loaded P06-1103.txt
# Loaded P85-1018.txt
# Loaded C02-1144.txt
# Loaded D08-1059.txt
# Loaded P05-1013.txt
# Loaded P02-1033.txt
# Loaded P06-1123.txt
# Loaded D10-1119.txt
# Loaded W04-3103.txt
# Loaded P06-1014.txt
# Loaded I05-3027.txt
# Loaded P08-1088.txt
# Loaded W08-2102.txt
# Loaded A97-1011.txt
# Loaded N03-1030.txt
# Loaded P95-1037.txt
# Loaded P02-1060.txt
# Loaded P05-1072.txt
# Loaded P08-1086.txt
# Loaded W03-0425.txt
# Loaded P98-2177.txt
# Loaded P06-1095.txt
# Loaded N04-1042.txt
# Loaded H05-1053.txt
# Loaded W02-1021.txt
# Loaded W04-0811.txt
# Loaded W09-1304.txt
# Loaded P00-1065.txt
# Loaded E03-1009.txt
# Loaded W04-3207.txt
# Loaded W10-3001.txt
# Loaded W06-1639.txt
# Loaded P06-2101.txt
# Loaded W11-1802.txt
# Loaded P08-2012.txt
# Loaded W03-1008.txt
# Loaded D09-1098.txt
# Loaded P92-1008.txt
# Loaded W01-0513.txt
# Loaded A00-2019.txt
# Loaded N13-1039.txt
# Loaded P93-1002.txt
# Loaded P99-1014.txt
# Loaded P04-1035.txt
# Loaded D08-1035.txt
# Loaded P95-1007.txt
# Loaded C08-1114.txt
# Loaded W03-1014.txt
# Loaded P06-1077.txt
# Loaded P08-1076.txt
# Loaded W04-3252.txt
# Loaded W04-3253.txt
# Loaded N13-1090.txt
# Loaded P04-1075.txt
# Loaded W00-1201.txt
# Loaded P03-1011.txt
# Loaded P05-1074.txt
# Loaded P98-1081.txt
# Loaded P09-2004.txt
# Loaded N03-1022.txt
# Loaded W07-0702.txt
# Loaded P08-1085.txt
# Loaded P97-1003.txt
# Loaded C04-1080.txt
# Loaded P08-1114.txt
# Loaded P96-1021.txt
# Loaded P04-1013.txt
# Loaded E06-1015.txt
# Loaded J87-1005.txt
# Loaded A00-2009.txt
# Loaded W02-0908.txt
# Loaded P06-1043.txt
# Loaded E06-1005.txt
# Loaded W06-2501.txt
# Loaded P03-1013.txt
# Loaded P94-1002.txt
# Loaded P00-1041.txt
# Loaded D10-1120.txt
# Loaded N03-1026.txt
# Loaded D07-1080.txt
# Loaded N03-2002.txt
# Loaded P99-1016.txt
# Loaded D07-1076.txt
# Loaded E06-1042.txt
# Loaded P95-1034.txt
# Loaded W06-2932.txt
# Loaded N07-1018.txt
# Loaded P91-1022.txt
# Loaded W97-0209.txt
# Loaded P00-1027.txt
# Loaded P02-1006.txt
# Loaded N07-1011.txt
# Loaded C04-1146.txt
# Loaded P06-1010.txt
# Loaded P90-1005.txt
# Loaded W98-1115.txt
# Loaded W95-0115.txt
# Loaded P07-1092.txt
# Loaded P97-1041.txt
# Loaded P10-2041.txt
# Loaded P98-1010.txt
# Loaded D11-1006.txt
# Loaded P00-1058.txt
# Loaded W09-0424.txt
# Loaded W95-0107.txt
# Loaded P04-1041.txt
# Loaded D10-1048.txt
# Loaded P04-1043.txt
# Loaded D10-1125.txt
# Loaded P05-1044.txt
# Loaded W97-0802.txt
# Loaded C04-1200.txt
# Loaded C04-1111.txt
# Loaded D10-1001.txt
# Loaded A97-1052.txt
# Loaded D08-1092.txt
# Loaded C02-1054.txt
# Loaded P96-1006.txt
# Loaded E99-1010.txt
# Loaded W05-0904.txt
# Loaded P97-1023.txt
# Loaded P05-2008.txt
# Loaded P09-1094.txt
# Loaded D08-1014.txt
# Loaded D07-1097.txt
# Loaded P06-3002.txt
# Loaded W03-1810.txt
# Loaded P08-1036.txt
# Loaded W03-0430.txt
# Loaded P07-1125.txt
# Loaded D10-1044.txt
# Loaded P02-1050.txt
# Loaded W04-3247.txt
# Loaded P09-1058.txt
# Loaded W99-0625.txt
# Loaded W03-0404.txt
# Loaded P02-1046.txt
# Loaded W03-1028.txt
# Loaded W96-0102.txt
# Loaded N04-1016.txt
# Loaded N12-1067.txt
# Loaded W11-2123.txt
# Loaded W11-1801.txt
# Loaded W03-1011.txt
# Loaded P94-1013.txt
# Loaded D11-1014.txt
# Loaded E09-1005.txt
# Loaded C90-3045.txt
000003, 19.500000000000004, 19.6, 18.7, 20.0, 21.1, 20.0, 18.700000000000003, 19.400000000000002, 23.5, 19.0, 18.9, 19.6, 20.900000000000002, 21.4, 17.3, 21.6, 23.900000000000002, 20.000000000000004, 23.900000000000002, 22.400000000000002, 19.7, 20.400000000000002, 18.500000000000004, 21.8, 22.700000000000003, 23.6, 22.900000000000002, 23.200000000000003, 20.5, 19.8, 20.5, 20.0, 19.500000000000004, 26.2, 19.900000000000002, 19.800000000000004, 22.500000000000004, 21.400000000000002, 23.1, 20.200000000000003, 21.500000000000004, 20.400000000000002, 25.300000000000004, 33.0, 25.700000000000003, 23.6, 24.700000000000003, 25.400000000000002, 20.5]
# Adjacency matrix normalized.
# Building sentence relation graph for 177 sentences.
# Shape of sentence embeddings: (177, 300)
# Adjacency matrix shape: (177, 177)
# ...
# Processing document with 210 sentences.
# Processing document with 199 sentences.
# Processing document with 155 sentences.
# Processing document with 249 sentences.
# Processing document with 108 sentences.
# Processing document with 191 sentences.
# Processing document with 216 sentences.
# Processing document with 183 sentences.
# Processing document with 236 sentences.
# Processing document with 171 sentences.
# Processing document with 359 sentences.
# Processing document with 216 sentences.
# Processing document with 143 sentences.
# Processing document with 261 sentences.
# Processing document with 281 sentences.
# Processing document with 125 sentences.
# Processing document with 233 sentences.
# Processing document with 209 sentences.
# Processing document with 184 sentences.
# Processing document with 136 sentences.
# Processing document with 110 sentences.
# Processing document with 271 sentences.
# Processing document with 190 sentences.
# Processing document with 229 sentences.
# Processing document with 328 sentences.
# Processing document with 246 sentences.
# Processing document with 145 sentences.
# Processing document with 124 sentences.
# Processing document with 237 sentences.
# Processing document with 184 sentences.
# Processing document with 125 sentences.
# Processing document with 273 sentences.
# Processing document with 178 sentences.
# Processing document with 320 sentences.
# Processing document with 193 sentences.
# Processing document with 123 sentences.
# Processing document with 293 sentences.
# Processing document with 12 sentences.
# Processing document with 220 sentences.
# Processing document with 175 sentences.
# Processing document with 219 sentences.
# Processing document with 245 sentences.
# Processing document with 187 sentences.
# Processing document with 230 sentences.
# Processing document with 207 sentences.
# Processing document with 194 sentences.
# Processing document with 116 sentences.
# Processing document with 146 sentences.
# Processing document with 268 sentences.
# Processing document with 251 sentences.
# Processing document with 245 sentences.
# Processing document with 110 sentences.
# Processing document with 167 sentences.
# Processing document with 478 sentences.
# Processing document with 249 sentences.
# Processing document with 232 sentences.
# Processing document with 145 sentences.
# Processing document with 369 sentences.
# Processing document with 232 sentences.
# Processing document with 242 sentences.
# Processing document with 146 sentences.
# Processing document with 201 sentences.
# Processing document with 1148 sentences.
# Processing document with 186 sentences.
# Processing document with 204 sentences.
# Processing document with 367 sentences.
# Processing document with 257 sentences.
# Processing document with 159 sentences.
# Processing document with 200 sentences.
# Processing document with 228 sentences.
# Processing document with 207 sentences.
# Processing document with 221 sentences.
# Processing document with 202 sentences.
# Processing document with 218 sentences.
# Processing document with 176 sentences.
# Processing document with 169 sentences.
# Processing document with 303 sentences.
# Processing document with 170 sentences.
# Processing document with 280 sentences.
# Processing document with 110 sentences.
# Processing document with 220 sentences.
# Processing document with 249 sentences.
# Processing document with 439 sentences.
# Processing document with 215 sentences.
# Processing document with 350 sentences.
# Processing document with 188 sentences.
# Processing document with 242 sentences.
# Processing document with 247 sentences.
# Processing document with 211 sentences.
# Processing document with 255 sentences.
# Processing document with 215 sentences.
# Processing document with 216 sentences.
# Processing document with 228 sentences.
# Processing document with 221 sentences.
# Processing document with 305 sentences.
# Processing document with 411 sentences.
# Processing document with 221 sentences.
# Processing document with 221 sentences.
# Processing document with 202 sentences.
# Processing document with 123 sentences.
# Processing document with 167 sentences.
# Processing document with 284 sentences.
# Processing document with 197 sentences.
# Processing document with 216 sentences.
# Processing document with 227 sentences.
# Processing document with 170 sentences.
# Processing document with 161 sentences.
# Processing document with 227 sentences.
# Processing document with 290 sentences.
# Processing document with 285 sentences.
# Processing document with 211 sentences.
# Processing document with 172 sentences.
# Processing document with 196 sentences.
# Processing document with 238 sentences.
# Processing document with 220 sentences.
# Processing document with 350 sentences.
# Processing document with 184 sentences.
# Processing document with 160 sentences.
# Processing document with 276 sentences.
# Processing document with 397 sentences.
# Processing document with 191 sentences.
# Processing document with 109 sentences.
# Processing document with 186 sentences.
# Processing document with 200 sentences.
# Processing document with 271 sentences.
# Processing document with 137 sentences.
# Processing document with 168 sentences.
# Processing document with 222 sentences.
# Processing document with 158 sentences.
# Processing document with 238 sentences.
# Processing document with 237 sentences.
# Processing document with 192 sentences.
# Processing document with 222 sentences.
# Processing document with 403 sentences.
# Processing document with 229 sentences.
# Processing document with 119 sentences.
# Processing document with 249 sentences.
# Processing document with 171 sentences.
# Processing document with 229 sentences.
# Processing document with 214 sentences.
# Processing document with 226 sentences.
# Processing document with 130 sentences.
# Processing document with 142 sentences.
# Processing document with 387 sentences.
# Processing document with 215 sentences.
# Processing document with 294 sentences.
# Processing document with 193 sentences.
# Processing document with 267 sentences.
# Processing document with 146 sentences.
# Processing document with 188 sentences.
# Processing document with 223 sentences.
# Processing document with 379 sentences.
# Processing document with 249 sentences.
# Processing document with 228 sentences.
# Processing document with 274 sentences.
# Processing document with 226 sentences.
# Processing document with 202 sentences.
# Processing document with 174 sentences.
# Processing document with 231 sentences.
# Processing document with 211 sentences.
# Processing document with 118 sentences.
# Processing document with 403 sentences.
# Processing document with 187 sentences.
# Processing document with 306 sentences.
# Processing document with 237 sentences.
# Processing document with 81 sentences.
# Processing document with 245 sentences.
# Processing document with 268 sentences.
# Processing document with 290 sentences.
# Processing document with 164 sentences.
# Processing document with 242 sentences.
# Processing document with 234 sentences.
# Processing document with 199 sentences.
# Processing document with 201 sentences.
# Processing document with 331 sentences.
# Processing document with 101 sentences.
# Processing document with 277 sentences.
# Processing document with 204 sentences.
# Processing document with 241 sentences.
# Processing document with 264 sentences.
# Processing document with 175 sentences.
# Processing document with 238 sentences.
# Processing document with 195 sentences.
# Processing document with 200 sentences.
# Processing document with 386 sentences.
# Processing document with 203 sentences.
# Processing document with 226 sentences.
# Processing document with 218 sentences.
# Processing document with 219 sentences.
# Processing document with 163 sentences.
# Processing document with 142 sentences.
# Processing document with 283 sentences.
# Processing document with 242 sentences.
# Processing document with 194 sentences.
# Processing document with 303 sentences.
# Processing document with 217 sentences.
# Processing document with 182 sentences.
# Processing document with 95 sentences.
# Processing document with 173 sentences.
# Processing document with 81 sentences.
# Processing document with 251 sentences.
# Processing document with 162 sentences.
# Processing document with 226 sentences.
# Processing document with 207 sentences.
# Processing document with 265 sentences.
# Processing document with 267 sentences.
# Processing document with 221 sentences.
# Processing document with 152 sentences.
# Processing document with 136 sentences.
# Processing document with 227 sentences.
# Processing document with 276 sentences.
# Processing document with 205 sentences.
# Processing document with 248 sentences.
# Processing document with 140 sentences.
# Processing document with 194 sentences.
# Processing document with 244 sentences.
# Processing document with 208 sentences.
# Processing document with 274 sentences.
# Processing document with 208 sentences.
# Processing document with 133 sentences.
# Processing document with 162 sentences.
# Processing document with 161 sentences.
# Processing document with 78 sentences.
# Processing document with 142 sentences.
# Processing document with 222 sentences.
# Processing document with 228 sentences.
# Processing document with 280 sentences.
# Processing document with 91 sentences.
# Processing document with 113 sentences.
# Processing document with 264 sentences.
# Processing document with 159 sentences.
# Processing document with 165 sentences.
# Processing document with 268 sentences.
# Processing document with 248 sentences.
# Processing document with 227 sentences.
# Processing document with 371 sentences.
# Processing document with 128 sentences.
# Processing document with 93 sentences.
# Processing document with 150 sentences.
# Processing document with 252 sentences.
# Processing document with 213 sentences.
# Processing document with 244 sentences.
# Processing document with 247 sentences.
# Processing document with 298 sentences.
# Processing document with 228 sentences.
# Processing document with 176 sentences.
# Processing document with 179 sentences.
# Processing document with 284 sentences.
# Processing document with 208 sentences.
# Processing document with 268 sentences.
# Processing document with 290 sentences.
# Processing document with 170 sentences.
# Processing document with 258 sentences.
# Processing document with 228 sentences.
# Processing document with 169 sentences.
# Processing document with 100 sentences.
# Processing document with 243 sentences.
# Processing document with 95 sentences.
# Processing document with 132 sentences.
# Processing document with 170 sentences.
# Processing document with 204 sentences.
# Processing document with 121 sentences.
# Processing document with 161 sentences.
# Processing document with 279 sentences.
# Processing document with 260 sentences.
# Processing document with 169 sentences.
# Processing document with 204 sentences.
# Processing document with 228 sentences.
# Processing document with 225 sentences.
# Processing document with 231 sentences.
# Processing document with 262 sentences.
# Processing document with 462 sentences.
# Processing document with 188 sentences.
# Processing document with 161 sentences.
# Processing document with 265 sentences.
# Processing document with 220 sentences.
# Processing document with 230 sentences.
# Processing document with 315 sentences.
# Processing document with 195 sentences.
# Processing document with 132 sentences.
# Processing document with 282 sentences.
# Processing document with 210 sentences.
# Processing document with 368 sentences.
# Processing document with 99 sentences.
# Processing document with 160 sentences.
# Processing document with 424 sentences.
# Processing document with 265 sentences.
# Processing document with 229 sentences.
# Processing document with 156 sentences.
# Processing document with 249 sentences.
# Processing document with 199 sentences.
# Processing document with 127 sentences.
# Processing document with 283 sentences.
# Processing document with 129 sentences.
# Processing document with 156 sentences.
# Processing document with 382 sentences.
# Processing document with 202 sentences.
# Processing document with 169 sentences.
# Processing document with 179 sentences.
# Processing document with 237 sentences.
# Processing document with 210 sentences.
# Processing document with 226 sentences.
# Processing document with 112 sentences.
# Processing document with 188 sentences.
# Processing document with 343 sentences.
# Processing document with 146 sentences.
# Processing document with 134 sentences.
# Processing document with 186 sentences.
# Processing document with 341 sentences.
# Processing document with 279 sentences.
# Processing document with 280 sentences.
# Processing document with 311 sentences.
# Processing document with 265 sentences.
# Processing document with 161 sentences.
# Processing document with 295 sentences.
# Processing document with 437 sentences.
# Processing document with 341 sentences.
# Processing document with 336 sentences.
# Processing document with 189 sentences.
# Processing document with 331 sentences.
# Processing document with 227 sentences.
# Processing document with 129 sentences.
# Processing document with 147 sentences.
# Processing document with 187 sentences.
# Processing document with 173 sentences.
# Processing document with 262 sentences.
# Processing document with 198 sentences.
# Processing document with 285 sentences.
# Processing document with 177 sentences.
# Processing document with 169 sentences.
# Processing document with 259 sentences.
# Processing document with 109 sentences.
# Processing document with 166 sentences.
# Processing document with 187 sentences.
# Processing document with 161 sentences.
# Processing document with 156 sentences.
# Processing document with 229 sentences.
# Processing document with 570 sentences.
# Processing document with 262 sentences.
# Processing document with 220 sentences.
# Processing document with 262 sentences.
# Processing document with 248 sentences.
# Processing document with 273 sentences.
# Processing document with 126 sentences.
# Processing document with 352 sentences.
# Processing document with 119 sentences.
# Processing document with 134 sentences.
# Processing document with 243 sentences.
# Processing document with 360 sentences.
# Processing document with 252 sentences.
# Processing document with 152 sentences.
# Processing document with 164 sentences.
# Processing document with 182 sentences.
# Processing document with 243 sentences.
# Processing document with 238 sentences.
# Processing document with 389 sentences.
# Processed document clusters through GRU. Shape: torch.Size([608, 1, 128])
# Shape of sentence_encodings before: torch.Size([608, 1, 128])
# Shape of sentence_encodings after: torch.Size([608, 128])
# Shape of adj_tensor: torch.Size([331, 331])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-4be43f57cbbd> in <cell line: 220>()
#     218
#     219 # Apply the GCN layer to the sentence encodings and adjacency matrix
# --> 220 gcn_output = gcn(sentence_encodings, adj_tensor)
#     221
#     222 # Print the shape of the output
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-19-4be43f57cbbd> in forward(self, x, adj)
#     163     def forward(self, x, adj):
#     164         adj = self.normalize_adj(adj)
# --> 165         assert adj.shape[0] == x.shape[0], "Dimension mismatch: adj and x must have the same number of nodes."
#     166
#     167         x = torch.matmul(adj, x)
#
# AssertionError: Dimension mismatch: adj and x must have the same number of nodes.

# %%
# Tokenization using spaCy
def tokenize_with_spacy(text):
    doc = nlp(text)
    return [token.text for token in doc]

# Get sentence embeddings using spaCy vectors
def get_embeddings_with_spacy(text):
    doc = nlp(text)
    return doc.vector  # Returns a 1D vector of the document

# Function to split document into sentences
def split_into_sentences(text):
    sentences = text.split('.')
    return [sentence.strip() for sentence in sentences if sentence]

# %%
# Custom function to calculate cosine similarity with a threshold
from sklearn.preprocessing import normalize

def cosine_similarity_threshold(embeddings, threshold=0.1):
    # Normalize the embeddings
    embeddings = normalize(embeddings)
    sim_matrix = cosine_similarity(embeddings)
    adj_matrix = (sim_matrix > threshold).astype(float)  # Apply threshold to create edges
    return adj_matrix


# Extract sentence features
def extract_sentence_features(sentences):
    features = []
    for i, sentence in enumerate(sentences):
        length = len(sentence.split())
        features.append({
            'position': i,
            'length': length,
            'proper_nouns': sum([1 for token in tokenize_with_spacy(sentence) if token.isupper()]),
            'is_first_three': 1 if i < 3 else 0
        })
    return features

# Calculate sentence personalization score
def calculate_personalization_scores(features):
    weights = {
        'position': 0.1,
        'length': 0.2,
        'proper_nouns': 0.4,
        'is_first_three': 0.3
    }
    personalization_scores = []
    for feature in features:
        score = sum([feature[key] * weights[key] for key in weights])
        personalization_scores.append(score)
    return personalization_scores

# Build the sentence relation graph using cosine similarity and personalization
def build_sentence_relation_graph(sentences, threshold=0.2):
    sentence_embeddings = [get_embeddings_with_spacy(sentence) for sentence in sentences]
    sentence_embeddings = np.vstack(sentence_embeddings)

    adj_matrix = cosine_similarity_threshold(sentence_embeddings, threshold)
    sentence_features = extract_sentence_features(sentences)
    personalization_scores = calculate_personalization_scores(sentence_features)

    for i in range(adj_matrix.shape[0]):
        for j in range(adj_matrix.shape[1]):
            if adj_matrix[i, j] > 0:
                adj_matrix[i, j] *= personalization_scores[i]

    adj_matrix = adj_matrix / adj_matrix.max()
    return adj_matrix

# %%
class GRUSentenceEncoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(GRUSentenceEncoder, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)

    def forward(self, x):
        _, h_n = self.gru(x)
        return h_n.squeeze(0)

# Processing document cluster through the GRU
from torch.nn.utils.rnn import pad_sequence

def process_document_cluster_through_gru(documents, hidden_size=128):
    input_size = 300  # SpaCy vectors are 300-dimensional
    encoder = GRUSentenceEncoder(input_size, hidden_size).to(device)

    sentence_encodings = []
    for doc in documents:
        sentences = split_into_sentences(doc)
        sentence_embeddings = [torch.tensor(get_embeddings_with_spacy(sentence)).to(device) for sentence in sentences]

        # Padding sentence embeddings to ensure uniform shape
        embeddings_tensor = pad_sequence(sentence_embeddings, batch_first=True).unsqueeze(0).to(device)

        # Ensure that the input tensor shape is correct for GRU
        sentence_encoding = encoder(embeddings_tensor)
        sentence_encodings.append(sentence_encoding)

    return torch.stack(sentence_encodings)

# %%
class GCNLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCNLayer, self).__init__()
        self.fc = nn.Linear(in_channels, out_channels)

    def forward(self, x, adj):
        x = self.fc(x)
        adj = self.normalize_adj(adj)
        x = torch.matmul(adj, x)
        return F.relu(x)

    def normalize_adj(self, adj):
        num_nodes = adj.size(0)
        I = torch.eye(num_nodes).to(device)
        adj = adj + I
        D = torch.sum(adj, dim=1)
        D_inv_sqrt = torch.pow(D, -0.5)
        D_inv_sqrt[torch.isinf(D_inv_sqrt)] = 0
        D_inv_sqrt = torch.diag(D_inv_sqrt)
        return torch.matmul(D_inv_sqrt, torch.matmul(adj, D_inv_sqrt))

# %%
class DocumentClusterEncoder(nn.Module):
    def __init__(self, sentence_input_size, sentence_hidden_size, doc_input_size, doc_hidden_size):
        super(DocumentClusterEncoder, self).__init__()
        self.sentence_encoder = GRUSentenceEncoder(sentence_input_size, sentence_hidden_size)
        self.doc_encoder = GRUSentenceEncoder(sentence_hidden_size, doc_hidden_size)

    def forward(self, document_clusters):
        document_embeddings = []

        for doc_cluster in document_clusters:
            sentence_embeddings = self.sentence_encoder(doc_cluster)
            sentence_embeddings = sentence_embeddings.unsqueeze(0)
            doc_embedding = self.doc_encoder(sentence_embeddings)
            document_embeddings.append(doc_embedding)

        document_embeddings = torch.stack(document_embeddings)
        cluster_embedding = torch.mean(document_embeddings, dim=0)
        return cluster_embedding

# %%
class SalienceEstimator(nn.Module):
    def __init__(self, hidden_size):
        super(SalienceEstimator, self).__init__()
        self.W1 = nn.Linear(hidden_size, hidden_size)
        self.W2 = nn.Linear(hidden_size, hidden_size)
        self.v = nn.Parameter(torch.randn(hidden_size))

    def forward(self, sentence_embeddings, cluster_embedding):
        cluster_embedding = cluster_embedding.unsqueeze(0)
        scores = torch.matmul(
            F.tanh(self.W1(cluster_embedding) + self.W2(sentence_embeddings)),
            self.v
        )
        salience_scores = F.softmax(scores.squeeze(0), dim=0)
        return salience_scores

# %%
import torch

# Define the device to use: GPU if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Read and process documents
documents = read_document_cluster(summaries_dir)
sentences_per_document = [split_into_sentences(doc) for doc in documents]
# first_document = documents[0]
# sentences_per_document = split_into_sentences(first_document)

print("done with sentences")

# Build sentence relation graphs for each document
adj_matrices = [build_sentence_relation_graph(sentences) for sentences in sentences_per_document]
print("done with adj_matrices")

# Process documents through GRU
sentence_encodings = process_document_cluster_through_gru(documents, hidden_size=128)
#sentence_encodings = process_document_cluster_through_gru([first_document], hidden_size=128)
print("done with encodings")

# Example usage of GCN layer
gcn = GCNLayer(128, 64).to(device)
adj_tensor = torch.tensor(adj_matrices[0], dtype=torch.float32).to(device)
sentence_encodings = sentence_encodings.to(device)

# Check the shape of the sentence encodings
# Check the shape of the sentence encodings
print(f"Shape of sentence_encodings before: {sentence_encodings.shape}")

# Ensure that the encodings have the correct dimensions [num_sentences, embedding_size]
if len(sentence_encodings.shape) == 3 and sentence_encodings.shape[1] == 1:
    sentence_encodings = sentence_encodings.squeeze(1)  # Remove extra dimension if needed

print(f"Shape of sentence_encodings after: {sentence_encodings.shape}")

# Apply the GCN layer to the sentence encodings and adjacency matrix
gcn_output = gcn(sentence_encodings, adj_tensor)

print("GCN output: ", gcn_output)
# Out:
# done with sentences
# done with adj_matrices
# done with encodings
# Shape of sentence_encodings before: torch.Size([608, 1, 128])
# Shape of sentence_encodings after: torch.Size([608, 1, 128])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-470ef8bbb6e1> in <cell line: 38>()
#      36
#      37 # Apply the GCN layer to the sentence encodings and adjacency matrix
# ---> 38 gcn_output = gcn(sentence_encodings, adj_tensor)
#      39
#      40 print("GCN output: ", gcn_output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-11-ecbf5b01b0cc> in forward(self, x, adj)
#       7         x = self.fc(x)
#       8         adj = self.normalize_adj(adj)
# ----> 9         x = torch.matmul(adj, x)
#      10         return F.relu(x)
#      11
#
# RuntimeError: Expected size for first two dimensions of batch2 tensor to be: [608, 331] but got: [608, 1].

# %%
import os
import torch
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rouge_score import rouge_scorer  # Ensure rouge_score is installed: pip install rouge-score

# Function to read document clusters from the dataset directory
def read_document_cluster(summaries_dir):
    documents = []
    summaries_files = os.listdir(summaries_dir)

    for file_name in summaries_files:
        file_path = os.path.join(summaries_dir, file_name)
        try:
            with open(file_path, 'r') as file:
                documents.append(file.read())
        except Exception as e:
            print(f"Error reading {file_name}: {e}")
    return documents

# Function to read reference summaries
def read_reference_summaries(reference_dir):
    references = {}
    summaries_files = os.listdir(reference_dir)

    for file_name in summaries_files:
        file_path = os.path.join(reference_dir, file_name)
        try:
            with open(file_path, 'r') as file:
                references[file_name] = file.read()
        except Exception as e:
            print(f"Error reading {file_name}: {e}")
    return references

# Sentence selection function
def select_sentences(salience_scores, sentences, length_limit=55, redundancy_threshold=0.5):
    if salience_scores.dim() > 1:
        salience_scores = salience_scores.squeeze(0)

    scores, indices = torch.sort(salience_scores, descending=True)
    selected_sentences = []
    current_length = 0
    tfidf_vectorizer = TfidfVectorizer()

    for idx in indices:
        sentence = sentences[idx]
        sentence_length = len(sentence.split())

        if current_length + sentence_length > length_limit:
            break

        if selected_sentences:
            all_sentences = selected_sentences + [sentence]
            tfidf_matrix = tfidf_vectorizer.fit_transform(all_sentences)
            cosine_similarities = cosine_similarity(tfidf_matrix[-1], tfidf_matrix[:-1])

            if cosine_similarities.max() > redundancy_threshold:
                continue

        selected_sentences.append(sentence)
        current_length += sentence_length

    return selected_sentences

# Function to calculate ROUGE scores
def calculate_rouge(reference_summary, generated_summary):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference_summary, generated_summary)
    return scores

# Path to the dataset and reference summaries
summaries_dir = '/content/drive/My Drive/Colab Notebooks/datasets/final/Whole_text_data'
reference_summaries_dir = '/content/drive/My Drive/Colab Notebooks/datasets/final/Summaries'

# Read the document cluster from the dataset
documents = read_document_cluster(summaries_dir)
reference_summaries = read_reference_summaries(reference_summaries_dir)

# Example function to get salience scores for sentences (replace with your actual model's output)
def get_salience_scores(num_sentences):
    return torch.rand(num_sentences)  # Random salience scores for now (replace with model output)

# Iterate over each document, generate a summary, and compute ROUGE scores
for doc_name, doc in zip(reference_summaries.keys(), documents):
    # Split document into sentences (you can replace this with a more sophisticated tokenizer)
    sentences = doc.split('. ')  # Simple sentence splitting by '. ' (adjust based on your data)

    # Get salience scores for each sentence (replace with your actual method)
    salience_scores = get_salience_scores(len(sentences))

    # Generate summary using sentence selection
    generated_summary_sentences = select_sentences(salience_scores, sentences, length_limit=100)
    generated_summary = ' '.join(generated_summary_sentences)

    # Get reference summary
    reference_summary = reference_summaries.get(doc_name, "Reference summary not found")  # Fallback text

    # Calculate ROUGE scores
    rouge_scores = calculate_rouge(reference_summary, generated_summary)

    # Print the results
    print(f"Document: {doc_name}")
    print("Generated Summary:")
    print(generated_summary)
    print("\nROUGE Scores:", rouge_scores)
    print("-" * 80)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-477084837f0f> in <cell line: 5>()
#       3 from sklearn.feature_extraction.text import TfidfVectorizer
#       4 from sklearn.metrics.pairwise import cosine_similarity
# ----> 5 from rouge_score import rouge_scorer  # Ensure rouge_score is installed: pip install rouge-score
#       6
#       7 # Function to read document clusters from the dataset directory
#
# ModuleNotFoundError: No module named 'rouge_score'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Complete Code
